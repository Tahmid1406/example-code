# %%
import rasterio
from rasterio.plot import show

# %%
src = rasterio.open('./data/Data/print.tif')
image = src.read()

# %%
image_norm = (image - image.min()) / (image.max() - image.min())
show(image_norm)
# Out:
# <AxesSubplot:>

# %%
show((src, 1), cmap='Reds', title='Red Channel')
show((src, 2), cmap='Greens', title='Green Channel')
show((src, 3), cmap='Blues', title='Blue Channel')
show((src, 4), cmap='Greys', title='Label Channel')
# Out:
# <AxesSubplot:title={'center':'Label Channel'}>
