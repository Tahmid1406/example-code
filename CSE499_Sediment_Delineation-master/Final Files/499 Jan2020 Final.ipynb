# %%
import warnings
from osgeo import gdal
from ipywidgets import IntProgress
import glob
import random
import cv2
import numpy as np
import tensorflow as tf
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from sklearn.model_selection import train_test_split
from PIL import Image
from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Recall, Precision
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers

# %%
seed = 42
lr = 1e-4

# %%
import os

input_dir = "./data/Data/Jan2020_image/"
target_dir = "./data/Data/Jan2020_mask/"
img_size = (256, 256)
num_classes = 5
batch_size = 32

input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(".tif")
    ]
)

target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(".tif")
    ]
)

n = 1500
input_img_paths = input_img_paths[n:]
target_img_paths = target_img_paths[n:]
input_img_paths = input_img_paths[:-n]
target_img_paths = target_img_paths[:-n]

print("Number of image samples:", len(input_img_paths))

print("Number of mask samples:", len(target_img_paths))
# Out:
# Number of image samples: 12762
# Number of mask samples: 12762

# %%
def read_original_mask(path):
    img = gdal.Open(path)
    x = img.ReadAsArray()
    x = np.array(x)
    x = np.array(Image.fromarray(x.astype(np.uint8)).resize((256, 256)))
    x[np.isnan(x)] = 0
    x = np.expand_dims(x, -1)
    #x = to_categorical(x,num_classes=5)
    #x = np.asarray(x, dtype=np.float32)
    print(x.shape, "read mask")
    return x


# land - green
# high - red
# moderate - yellow
# low - black
# water - blue

def make_colour_mask(segment_mask):
    colour_table = np.zeros((256, 1, 3), dtype=np.uint8)
    colour_table[0] = [0,128,0] 
    colour_table[1] = [255,0,0]
    colour_table[2] = [255,255,0]
    colour_table[3] = [0,0,0]
    colour_table[4] = [0,0,255]

    colour_mask = cv2.applyColorMap(segment_mask, colour_table)

    return colour_mask

# %%
ind = 1512
fp = input_img_paths[ind]
img = rasterio.open(fp)
show(img)



file = target_img_paths[ind]
im = read_original_mask(file)
img = make_colour_mask(im)
plt.imshow(img)
# Out:
# (256, 256, 1) read mask

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Normalize bands into 0.0 - 1.0 scale
def normalize(array):
    diff = array.max() - array.min()
    return (array - array.min()) / diff

def read_image(path):
    raster = rasterio.open(path)
    band_2 = raster.read(1)
    band_3 = raster.read(2)
    band_4 = raster.read(3)
    
    norm_2 = normalize(band_2)
    norm_3 = normalize(band_3)
    norm_4 = normalize(band_4)
    
    x = np.dstack((norm_4, norm_3, norm_2))
    image = np.array(x)
    image = np.array(Image.fromarray((x * 255).astype(np.uint8)).resize((256, 256)).convert('RGB'))
    image[np.isnan(image)] = 0
    image = np.asarray(image, dtype=np.float32)/255.0
    #print("image")
    #print(image.shape)
    #print(image)
    return image

def read_mask(path):
    img = gdal.Open(path)
    x = img.ReadAsArray()
    x = np.array(x)
    x = np.array(Image.fromarray(x.astype(np.uint8)).resize((256, 256)))
    x[np.isnan(x)] = 0
    x = np.expand_dims(x, -1)
    x = to_categorical(x,num_classes=5)
    x = np.asarray(x, dtype=np.float32)
    # print(x.shape, "read mask")
    return x

# %%
im = read_mask(target_img_paths[310])
#print(im.shape)
#print(im)

# %%
im2 = read_image(input_img_paths[310])

print("Shape of the iamges ", im2.shape)
print("Min and Max values of the images : ", im2.max(), im2.min())
# Out:
# Shape of the iamges  (256, 256, 3)
# Min and Max values of the images :  1.0 0.0

# %%
from tensorflow import keras
import numpy as np
from tensorflow.keras.preprocessing.image import load_img

from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical


class SATDATA(keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, batch_size, img_size, input_img_paths, target_img_paths):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_img_paths = input_img_paths
        self.target_img_paths = target_img_paths

    def __len__(self):
        return len(self.target_img_paths) // self.batch_size

    def __getitem__(self, idx):
        """Returns tuple (input, target) correspond to batch #idx."""
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="float32")
        
        for j, path in enumerate(batch_input_img_paths):
            #print(path)
            img = read_image(path)
            x[j] = img
            x[j] = np.stack(img)
            
        y = np.zeros((self.batch_size,) + self.img_size + (5,), dtype="float32")
        for j, path in enumerate(batch_target_img_paths):
            y[j] = read_mask(path)
         
        #print(x.shape, "  ", y.shape)
        return x, y

# %%
import random


# Split our img paths into a training and a validation set
val_samples = 3000
random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_img_paths)

train_input_img_paths = input_img_paths[:-val_samples]
train_target_img_paths = target_img_paths[:-val_samples]

# print(train_input_img_paths[100])
# print(train_target_img_paths[100])

val_input_img_paths = input_img_paths[-val_samples:]
val_target_img_paths = target_img_paths[-val_samples:]

# Instantiate data Sequences for each split
train_gen = SATDATA(batch_size, img_size, train_input_img_paths, train_target_img_paths)
val_gen = SATDATA(batch_size, img_size, val_input_img_paths, val_target_img_paths)

# %%
print(val_gen.__len__())
print(train_gen.__len__())
# Out:
# 93
# 305

# %%
# https://cdn-sv1.deepsense.ai/wp-content/uploads/2017/04/architecture_details.png
# https://deepsense.ai/deep-learning-for-satellite-imagery-via-image-segmentation/

from keras_unet import TF
if TF:
    from tensorflow.keras.models import Model
    from tensorflow.keras.layers import ( 
        BatchNormalization, Conv2D, Conv2DTranspose,
        MaxPooling2D, UpSampling2D, Input,
        concatenate
    )
else:    
    from keras.models import Model
    from keras.layers import ( 
        BatchNormalization, Conv2D, Conv2DTranspose,
        MaxPooling2D, UpSampling2D, Input,
        concatenate
    )


def bn_conv_relu(input, filters, bachnorm_momentum, **conv2d_args):
    x = BatchNormalization(momentum=bachnorm_momentum)(input)
    x = Conv2D(filters, **conv2d_args)(x)
    return x

def bn_upconv_relu(input, filters, bachnorm_momentum, **conv2d_trans_args):
    x = BatchNormalization(momentum=bachnorm_momentum)(input)
    x = Conv2DTranspose(filters, **conv2d_trans_args)(x)
    return x

def satellite_unet(
    input_shape,
    num_classes=5,
    output_activation='softmax',
    num_layers=4):

    inputs = Input(input_shape)   
    
    filters = 64
    upconv_filters = 96

    kernel_size = (3,3)
    activation = 'relu'
    strides = (1,1)
    padding = 'same'
    kernel_initializer = 'he_normal'

    conv2d_args = {
        'kernel_size':kernel_size,
        'activation':activation, 
        'strides':strides,
        'padding':padding,
        'kernel_initializer':kernel_initializer
        }

    conv2d_trans_args = {
        'kernel_size':kernel_size,
        'activation':activation, 
        'strides':(2,2),
        'padding':padding,
        'output_padding':(1,1)
        }

    bachnorm_momentum = 0.01

    pool_size = (2,2)
    pool_strides = (2,2)
    pool_padding = 'valid'

    maxpool2d_args = {
        'pool_size':pool_size,
        'strides':pool_strides,
        'padding':pool_padding,
        }
    
    x = Conv2D(filters, **conv2d_args)(inputs)
    c1 = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)    
    x = bn_conv_relu(c1, filters, bachnorm_momentum, **conv2d_args)
    x = MaxPooling2D(**maxpool2d_args)(x)

    down_layers = []

    for l in range(num_layers):
        x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
        x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
        down_layers.append(x)
        x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
        x = MaxPooling2D(**maxpool2d_args)(x)

    x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
    x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
    x = bn_upconv_relu(x, filters, bachnorm_momentum, **conv2d_trans_args)

    for conv in reversed(down_layers):        
        x = concatenate([x, conv])  
        x = bn_conv_relu(x, upconv_filters, bachnorm_momentum, **conv2d_args)
        x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
        x = bn_upconv_relu(x, filters, bachnorm_momentum, **conv2d_trans_args)

    x = concatenate([x, c1])
    x = bn_conv_relu(x, upconv_filters, bachnorm_momentum, **conv2d_args)
    x = bn_conv_relu(x, filters, bachnorm_momentum, **conv2d_args)
           
    outputs = Conv2D(5, kernel_size=(1,1), strides=(1,1), activation=output_activation, padding='valid') (x)   
    
    print("output data")
    print(outputs.shape)
    
    model = Model(inputs=[inputs], outputs=[outputs])
    return model



# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = satellite_unet(input_shape=(256, 256, 3))
model.summary()
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------
# output data
# (None, 256, 256, 5)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 64) 36928       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   36928       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 64)   36928       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 64)   36928       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 64)   36928       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 64)   36928       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 64)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 64)     256         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     36928       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 64)     36928       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 64)     256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 64)   36928       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 128)  0           conv2d_transpose[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 128)  512         concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 96)   110688      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 96)   384         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 64)   55360       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 64)   36928       batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 96)   110688      batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 96)   384         conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 64)   55360       batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   36928       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 128)  512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 96)   110688      batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 96)   384         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 64)   55360       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 64) 36928       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 128, 128, 128 512         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 96) 110688      batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 128, 128, 96) 384         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 64) 55360       batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 128, 128, 64) 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 64) 36928       batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 256, 256, 128 512         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 96) 110688      batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 256, 256, 96) 384         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 64) 55360       batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 5)  325         conv2d_26[0][0]
# ==================================================================================================
# Total params: 1,617,701
# Trainable params: 1,612,773
# Non-trainable params: 4,928
# __________________________________________________________________________________________________

# %%
def dice_coef(y_true, y_pred, smooth=1):
    """
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    ref: https://arxiv.org/pdf/1606.04797v1.pdf
    """
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    return (2. * intersection + smooth) / (K.sum(K.square(y_true),-1) + K.sum(K.square(y_pred),-1) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
# Configure the model for training.
# We use the "sparse" version of categorical_crossentropy
# because our target data is integers.
from keras.optimizers import Adam, SGD
from keras_unet.metrics import iou, iou_thresholded
#from keras_unet.losses import jaccard_distance

from keras.callbacks import ModelCheckpoint


val_len = val_gen.__len__()
train_len = train_gen.__len__()

steps_per_ep = train_len // batch_size

model_filename = 'Jan2020.h5'
callback_checkpoint = ModelCheckpoint(
    model_filename, 
    verbose=1, 
    monitor='val_loss', 
    save_best_only=True,
)


model.compile(optimizer=Adam( lr = 1e-4, decay=1e-5),
              loss='categorical_crossentropy',
              metrics= [dice_coef, 'accuracy']
              )


# Train the model, doing validation at the end of each epoch.
epochs = 30
history = model.fit(train_gen, 
                    epochs=epochs, 
                    steps_per_epoch=steps_per_ep, 
                    validation_data=val_gen, 
                    callbacks=[callback_checkpoint])
# Out:
# Epoch 1/30
# 9/9 [==============================] - 1427s 172s/step - loss: 2.0835 - dice_coef: 0.5946 - accuracy: 0.2061 - val_loss: 1.7498 - val_dice_coef: 0.6582 - val_accuracy: 0.3493
#
# Epoch 00001: val_loss improved from inf to 1.74977, saving model to Jan2020.h5
# Epoch 2/30
# 9/9 [==============================] - 1469s 177s/step - loss: 1.5815 - dice_coef: 0.6854 - accuracy: 0.4015 - val_loss: 1.4088 - val_dice_coef: 0.7209 - val_accuracy: 0.4845
#
# Epoch 00002: val_loss improved from 1.74977 to 1.40880, saving model to Jan2020.h5
# Epoch 3/30
# 9/9 [==============================] - 1462s 176s/step - loss: 1.3946 - dice_coef: 0.7194 - accuracy: 0.4751 - val_loss: 1.2697 - val_dice_coef: 0.7438 - val_accuracy: 0.5343
#
# Epoch 00003: val_loss improved from 1.40880 to 1.26972, saving model to Jan2020.h5
# Epoch 4/30
# 9/9 [==============================] - 1467s 176s/step - loss: 1.1962 - dice_coef: 0.7541 - accuracy: 0.5532 - val_loss: 1.1112 - val_dice_coef: 0.7747 - val_accuracy: 0.5995
#
# Epoch 00004: val_loss improved from 1.26972 to 1.11118, saving model to Jan2020.h5
# Epoch 5/30
# 9/9 [==============================] - 1467s 176s/step - loss: 1.0599 - dice_coef: 0.7795 - accuracy: 0.6050 - val_loss: 1.1631 - val_dice_coef: 0.7792 - val_accuracy: 0.5962
#
# Epoch 00005: val_loss did not improve from 1.11118
# Epoch 6/30
# 9/9 [==============================] - 1458s 175s/step - loss: 1.1347 - dice_coef: 0.7675 - accuracy: 0.5705 - val_loss: 0.9860 - val_dice_coef: 0.8025 - val_accuracy: 0.6502
#
# Epoch 00006: val_loss improved from 1.11118 to 0.98603, saving model to Jan2020.h5
# Epoch 7/30
# 9/9 [==============================] - 1464s 176s/step - loss: 1.0600 - dice_coef: 0.7720 - accuracy: 0.5708 - val_loss: 1.0081 - val_dice_coef: 0.7858 - val_accuracy: 0.5988
#
# Epoch 00007: val_loss did not improve from 0.98603
# Epoch 8/30
# 9/9 [==============================] - 1465s 176s/step - loss: 0.9441 - dice_coef: 0.7971 - accuracy: 0.6246 - val_loss: 0.9295 - val_dice_coef: 0.8060 - val_accuracy: 0.6559
#
# Epoch 00008: val_loss improved from 0.98603 to 0.92947, saving model to Jan2020.h5
# Epoch 9/30
# 9/9 [==============================] - 1465s 176s/step - loss: 0.9371 - dice_coef: 0.7992 - accuracy: 0.6319 - val_loss: 0.8903 - val_dice_coef: 0.8153 - val_accuracy: 0.6728
#
# Epoch 00009: val_loss improved from 0.92947 to 0.89033, saving model to Jan2020.h5
# Epoch 10/30
# 9/9 [==============================] - 1471s 177s/step - loss: 0.8306 - dice_coef: 0.8317 - accuracy: 0.7185 - val_loss: 0.9031 - val_dice_coef: 0.8251 - val_accuracy: 0.6935
#
# Epoch 00010: val_loss did not improve from 0.89033
# Epoch 11/30
# 9/9 [==============================] - 1461s 176s/step - loss: 0.8646 - dice_coef: 0.8248 - accuracy: 0.6928 - val_loss: 0.8459 - val_dice_coef: 0.8280 - val_accuracy: 0.6992
#
# Epoch 00011: val_loss improved from 0.89033 to 0.84587, saving model to Jan2020.h5
# Epoch 12/30
# 9/9 [==============================] - 1473s 177s/step - loss: 1.0048 - dice_coef: 0.7952 - accuracy: 0.6202 - val_loss: 0.8272 - val_dice_coef: 0.8272 - val_accuracy: 0.6821
#
# Epoch 00012: val_loss improved from 0.84587 to 0.82715, saving model to Jan2020.h5
# Epoch 13/30
# 9/9 [==============================] - 1469s 177s/step - loss: 0.7663 - dice_coef: 0.8362 - accuracy: 0.7089 - val_loss: 1.3765 - val_dice_coef: 0.7947 - val_accuracy: 0.6406
#
# Epoch 00013: val_loss did not improve from 0.82715
# Epoch 14/30
# 9/9 [==============================] - 1468s 176s/step - loss: 0.8952 - dice_coef: 0.8163 - accuracy: 0.6803 - val_loss: 0.8704 - val_dice_coef: 0.8258 - val_accuracy: 0.6965
#
# Epoch 00014: val_loss did not improve from 0.82715
# Epoch 15/30
# 9/9 [==============================] - 1467s 176s/step - loss: 0.8923 - dice_coef: 0.8137 - accuracy: 0.6657 - val_loss: 0.8345 - val_dice_coef: 0.8211 - val_accuracy: 0.6794
#
# Epoch 00015: val_loss did not improve from 0.82715
# Epoch 16/30
# 9/9 [==============================] - 1465s 176s/step - loss: 0.7681 - dice_coef: 0.8357 - accuracy: 0.7088 - val_loss: 0.7714 - val_dice_coef: 0.8385 - val_accuracy: 0.7166
#
# Epoch 00016: val_loss improved from 0.82715 to 0.77138, saving model to Jan2020.h5
# Epoch 17/30
# 9/9 [==============================] - 1471s 177s/step - loss: 0.7815 - dice_coef: 0.8358 - accuracy: 0.7183 - val_loss: 0.7501 - val_dice_coef: 0.8472 - val_accuracy: 0.7283
#
# Epoch 00017: val_loss improved from 0.77138 to 0.75006, saving model to Jan2020.h5
# Epoch 18/30
# 9/9 [==============================] - 1479s 178s/step - loss: 0.7423 - dice_coef: 0.8431 - accuracy: 0.7183 - val_loss: 0.7381 - val_dice_coef: 0.8464 - val_accuracy: 0.7334
#
# Epoch 00018: val_loss improved from 0.75006 to 0.73813, saving model to Jan2020.h5
# Epoch 19/30
# 9/9 [==============================] - 1452s 175s/step - loss: 0.7174 - dice_coef: 0.8453 - accuracy: 0.7142 - val_loss: 0.7688 - val_dice_coef: 0.8416 - val_accuracy: 0.7044
#
# Epoch 00019: val_loss did not improve from 0.73813
# Epoch 20/30
# 9/9 [==============================] - 1461s 176s/step - loss: 0.8390 - dice_coef: 0.8253 - accuracy: 0.6774 - val_loss: 0.7096 - val_dice_coef: 0.8537 - val_accuracy: 0.7437
#
# Epoch 00020: val_loss improved from 0.73813 to 0.70963, saving model to Jan2020.h5
# Epoch 21/30
# 9/9 [==============================] - 1469s 177s/step - loss: 0.8607 - dice_coef: 0.8241 - accuracy: 0.6873 - val_loss: 0.8020 - val_dice_coef: 0.8388 - val_accuracy: 0.7162
#
# Epoch 00021: val_loss did not improve from 0.70963
# Epoch 22/30
# 9/9 [==============================] - 1468s 176s/step - loss: 0.8496 - dice_coef: 0.8239 - accuracy: 0.6886 - val_loss: 0.9009 - val_dice_coef: 0.8162 - val_accuracy: 0.6466
#
# Epoch 00022: val_loss did not improve from 0.70963
# Epoch 23/30
# 9/9 [==============================] - 1459s 175s/step - loss: 0.7174 - dice_coef: 0.8460 - accuracy: 0.7180 - val_loss: 0.7121 - val_dice_coef: 0.8507 - val_accuracy: 0.7398
#
# Epoch 00023: val_loss did not improve from 0.70963
# Epoch 24/30
# 9/9 [==============================] - 1492s 179s/step - loss: 0.7419 - dice_coef: 0.8474 - accuracy: 0.7430 - val_loss: 0.6884 - val_dice_coef: 0.8576 - val_accuracy: 0.7540
#
# Epoch 00024: val_loss improved from 0.70963 to 0.68838, saving model to Jan2020.h5
# Epoch 25/30
# 9/9 [==============================] - 1467s 176s/step - loss: 0.7597 - dice_coef: 0.8389 - accuracy: 0.7094 - val_loss: 0.7063 - val_dice_coef: 0.8504 - val_accuracy: 0.7315
#
# Epoch 00025: val_loss did not improve from 0.68838
# Epoch 26/30
# 9/9 [==============================] - 1465s 176s/step - loss: 0.6676 - dice_coef: 0.8572 - accuracy: 0.7503 - val_loss: 0.6612 - val_dice_coef: 0.8609 - val_accuracy: 0.7583
#
# Epoch 00026: val_loss improved from 0.68838 to 0.66123, saving model to Jan2020.h5
# Epoch 27/30
# 9/9 [==============================] - 1474s 177s/step - loss: 0.7274 - dice_coef: 0.8550 - accuracy: 0.7538 - val_loss: 0.7258 - val_dice_coef: 0.8538 - val_accuracy: 0.7434
#
# Epoch 00027: val_loss did not improve from 0.66123
# Epoch 28/30
# 9/9 [==============================] - 1475s 177s/step - loss: 0.7776 - dice_coef: 0.8382 - accuracy: 0.7089 - val_loss: 0.6987 - val_dice_coef: 0.8592 - val_accuracy: 0.7511
#
# Epoch 00028: val_loss did not improve from 0.66123
# Epoch 29/30
# 9/9 [==============================] - 1480s 178s/step - loss: 0.6571 - dice_coef: 0.8596 - accuracy: 0.7502 - val_loss: 0.6761 - val_dice_coef: 0.8622 - val_accuracy: 0.7569
#
# Epoch 00029: val_loss did not improve from 0.66123
# Epoch 30/30
# 9/9 [==============================] - 1474s 177s/step - loss: 0.6715 - dice_coef: 0.8550 - accuracy: 0.7220 - val_loss: 0.7059 - val_dice_coef: 0.8552 - val_accuracy: 0.7471
#
# Epoch 00030: val_loss did not improve from 0.66123

# %%
print("Best Loss : ", min(history.history['loss']))
print("Best Validation Loss : ", min(history.history['val_loss']))

print("Best Accuracy : ", max(history.history['accuracy']))
print("Best Validation Accuracy : ", max(history.history['val_accuracy']))

print("Best Dice Coef : ", max(history.history['dice_coef']))

print("Best Validation Dice Coef : ", max(history.history['val_dice_coef']))
# Out:
# Best Loss :  0.6722373962402344
# Best Validation Loss :  0.6612295508384705
# Best Accuracy :  0.7525379657745361
# Best Validation Accuracy :  0.7583227753639221
# Best Dice Coef :  0.8576273918151855
# Best Validation Dice Coef :  0.8622426390647888

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(
    history, # required - keras training history object
    metrics=['dice_coef', 'val_dice_coef'], # optional - metrics names to plot
    losses=['loss', 'val_loss']) # optional - loss names to plot
